# %% [markdown]
# # **Import Packages**

# %%
import os
import time
import cv2
import io

import numpy as np
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import tensorflow as tf
import seaborn as sns

from PIL import Image
from warnings import filterwarnings
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# # **Data Loading**

# %%
x_train = [] # MRI image
y_train = [] # Label of the image
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']


image_size = 256
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-dataset/Training',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        x_train.append(img)
        y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('../input/brain-tumor-classification-dataset/Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        x_train.append(img)
        y_train.append(i)
        
x_train = np.array(x_train)
y_train = np.array(y_train)
# Out:
# 100%|██████████| 826/826 [00:01<00:00, 415.53it/s]
# 100%|██████████| 822/822 [00:01<00:00, 423.43it/s]
# 100%|██████████| 395/395 [00:00<00:00, 420.38it/s]
# 100%|██████████| 827/827 [00:02<00:00, 356.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 396.31it/s]
# 100%|██████████| 115/115 [00:00<00:00, 420.29it/s]
# 100%|██████████| 105/105 [00:00<00:00, 499.50it/s]
# 100%|██████████| 74/74 [00:00<00:00, 229.65it/s]

# %% [markdown]
# # **Visualization**

# %% [markdown]
# **Glioma Tumor:**
# >Originating in the brain or spine's glial cells, gliomas represent 30% of all brain and central nervous system tumors. They are mostly malignant, with symptoms that vary depending on location, frequently resulting in seizures, cognitive impairments, or motor deficits.
#
# **Meningioma Tumor:**
# >Meningiomas, arising from the meninges enveloping the brain and spinal cord, are slow-growing tumors. While they typically are asymptomatic, they can cause seizures, cognitive decline, vision disturbances, or motor deficits depending on their location.
#
# **Pituitary Tumor:**
# >Pituitary adenomas, mostly benign, occur in the pituitary gland, accounting for 10-25% of intracranial neoplasms. They may cause hormonal imbalances, resulting in a variety of symptoms including headaches, vision changes, or hormonal dysfunctions.

# %%
## Create a plot of the label and count of image

# Use a compressed for loop to create a object of the label and the count
label_counts = {label: np.sum(y_train == label) for label in labels}

# Stretch the graph
plt.figure(figsize=(8, 6))

colors = ["C0", "C1", "C2", "C3"]

bars = plt.bar(label_counts.keys(), label_counts.values(), color=colors)
plt.xlabel('Labels')
plt.ylabel('Count')
plt.title('Distribution of Labels')

plt.show()

# %% [markdown]
# # **Data Preparation**

# %%
# Convert the label to one-hot encoding format which converts the categorical data to numeric one
y_train = np.array(pd.get_dummies(y_train))

print(y_train)
# Out:
# [[ True False False False]
#  [ True False False False]
#  [ True False False False]
#  ...
#  [False False False  True]
#  [False False False  True]
#  [False False False  True]]

# %%
#Split the dataset into training, testing and validation sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.1,random_state=42)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.1, random_state=42)

print(f'X_train shape: {(x_train).shape}\n'
      f'y_train shape: {(y_train).shape}\n'
      f'X_test shape: {(x_test).shape}\n'
      f'y_test shape: {(y_test).shape}\n'
      f'X_valid shape: {(x_valid).shape}\n'
      f'y_valid shape: {(y_valid).shape}')
# Out:
# X_train shape: (2643, 256, 256, 3)
# y_train shape: (2643, 4)
# X_test shape: (327, 256, 256, 3)
# y_test shape: (327, 4)
# X_valid shape: (294, 256, 256, 3)
# y_valid shape: (294, 4)

# %% [markdown]
# # **Normalization**
# Normalization is the process of converting the pixel value from 0-255 to 0-1

# %%
# Normalize pixel values of training images to the range [0,1]
x_train = x_train / 255
x_test = x_test / 255
x_valid = x_valid / 255

print(f"Maximum and Minimum pixel value after normalization: {x_train.min()} - {x_train.max()}")
# Out:
# Maximum and Minimum pixel value after normalization: 0.0 - 1.0

# %% [markdown]
# # **Introduction to Convolution Neural Network**
#
# Convolutional Neural Networks (CNNs) are important in Deep Learning, particularly for Computer Vision, as they allow machines to understand and analyze visual data such as images. Neural Networks excel across a wide range of datasets in Machine Learning, including images, audio, and text. CNNs are especially useful for tasks such as image classification.
#
# <p>&nbsp;</p>
#
# In a typical Neural Network architecture, we encounter three key layers:
#
# 1. **Input Layer**: This initial layer acts as a gateway for model input. Its neuron count corresponds to the dataset's total features, such as the number of pixels in images.
#
# 2. **Hidden Layer**: Data moves from the input layer to the hidden layers, where complex transformations take place. These layers can vary in number and neuron count, allowing the network to capture complex patterns using matrix operations, weight adjustments, biases, and activation functions.
#
# 3. **Output Layer**: The output layer receives processed data from the hidden layers and uses functions such as sigmoid or softmax to calculate probability scores for various classes.
#
# <p>&nbsp;</p>
#
# <span style="color:crimson;">Feedforward</span> is the process of feeding data into a neural network model and then sequentially calculating the output from each layer until the final output layer. This step involves applying transformations and activation functions to the input data as it passes through the network.
#
#
# <span style="color:crimson;">Backpropagation</span>, on the other hand, is the process of changing the model's parameters (weights and biases) by computing the gradients of the loss function with respect to each parameter. These gradients are calculated using the chain rule of calculus and used to adjust the parameters in a way that reduces the loss function. This iterative process enables the model to learn from its mistakes and improves its performance over time.
#
# <p>&nbsp;</p>
#
# In a Convolutional Neural Network, various layers work to process input data, such as images. The Convolutional layer extracts features using filters, the Pooling layer reduces image size to improve efficiency, and the fully connected layer makes predictions. Backpropagation and gradient descent are used by the network to refine its filter parameters and improve its performance.
#
# <p>&nbsp;</p>
#
# *Source: [geeksforgeeks](https://www.geeksforgeeks.org/introduction-convolution-neural-network/)*

# %% [markdown]
# # **Model Training**

# %%
# Define the model
model = Sequential()

# An Input layer specifying the input shape
model.add(Input(shape=(256, 256, 3)))

# Hidden layer
model.add(Conv2D(32, kernel_size=(5,5), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.15))

model.add(Conv2D(32, kernel_size=(5,5), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.15))

model.add(Conv2D(32, kernel_size=(3,3), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.15))

model.add(Conv2D(64, kernel_size=(2,2), activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.15))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.45))

# Output layer
model.add(Dense(4, activation='softmax'))

# Model Config
model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Display the summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 256, 256, 32)   │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128, 128, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 128, 128, 32)   │        25,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 32, 32, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 16384)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │     2,097,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,143,364 (8.18 MB)
#  Trainable params: 2,143,364 (8.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **Compute Class Weights**

# %%
# Convert one-hot encoded labels back to integers for the calculation
y_train_integers = np.argmax(y_train, axis=1)

# Compute the weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_integers),
    y=y_train_integers
)

# Convert to a dictionary format for Keras
class_weight_dict = dict(enumerate(class_weights))
print("Computed Class Weights:", class_weight_dict)
# Out:
# Computed Class Weights: {0: 0.9051369863013699, 1: 0.878656914893617, 2: 1.6234643734643734, 3: 0.8763262599469496}

# %% [markdown]
# # **Define Callbacks & Save Condition**

# %%
# Stop training when validation loss stops improving for 10 epochs
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10, 
    restore_best_weights=True, 
    verbose=1
)

# Save the best model automatically
checkpoint = ModelCheckpoint(
    filepath='/kaggle/working/neuroscan_best.keras', 
    monitor='val_loss', 
    save_best_only=True, 
    verbose=1
)

# Reduce learning rate by half if validation loss plateaus for 5 epochs
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=5, 
    min_lr=1e-6, 
    verbose=1
)

# Group callbacks into a list
callbacks_list = [early_stopping, checkpoint, lr_scheduler]

# %% [markdown]
# # **Fit the model**

# %%
start_time = time.time()

batch_size = 64
epochs = 100

# Train the model using the data generator, callbacks, and class weights
history = model.fit(
    x_train, y_train, 
    batch_size=batch_size,
    validation_data=(x_valid, y_valid),
    epochs=epochs,
    callbacks=callbacks_list,
    class_weight=class_weight_dict,
    verbose=1
)

end_time = time.time()

runtime = end_time - start_time
print("Total runtime:", runtime, "seconds")
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.3205 - loss: 1.3515
# Epoch 1: val_loss improved from inf to 1.20123, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 18s 251ms/step - accuracy: 0.3222 - loss: 1.3497 - val_accuracy: 0.5000 - val_loss: 1.2012 - learning_rate: 0.0010
# Epoch 2/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.5753 - loss: 1.0372
# Epoch 2: val_loss improved from 1.20123 to 0.94480, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.5762 - loss: 1.0349 - val_accuracy: 0.6429 - val_loss: 0.9448 - learning_rate: 0.0010
# Epoch 3/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6381 - loss: 0.8397
# Epoch 3: val_loss improved from 0.94480 to 0.79234, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6387 - loss: 0.8392 - val_accuracy: 0.6361 - val_loss: 0.7923 - learning_rate: 0.0010
# Epoch 4/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7060 - loss: 0.7109
# Epoch 4: val_loss improved from 0.79234 to 0.62498, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7063 - loss: 0.7100 - val_accuracy: 0.7313 - val_loss: 0.6250 - learning_rate: 0.0010
# Epoch 5/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7645 - loss: 0.6019
# Epoch 5: val_loss did not improve from 0.62498
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7638 - loss: 0.6029 - val_accuracy: 0.6463 - val_loss: 0.7263 - learning_rate: 0.0010
# Epoch 6/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.7704 - loss: 0.5346
# Epoch 6: val_loss improved from 0.62498 to 0.55611, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7712 - loss: 0.5343 - val_accuracy: 0.8027 - val_loss: 0.5561 - learning_rate: 0.0010
# Epoch 7/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8033 - loss: 0.4788
# Epoch 7: val_loss improved from 0.55611 to 0.49830, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8035 - loss: 0.4780 - val_accuracy: 0.7789 - val_loss: 0.4983 - learning_rate: 0.0010
# Epoch 8/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8390 - loss: 0.3746
# Epoch 8: val_loss improved from 0.49830 to 0.48035, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8387 - loss: 0.3757 - val_accuracy: 0.8027 - val_loss: 0.4803 - learning_rate: 0.0010
# Epoch 9/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8420 - loss: 0.3627
# Epoch 9: val_loss improved from 0.48035 to 0.44309, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8425 - loss: 0.3623 - val_accuracy: 0.8367 - val_loss: 0.4431 - learning_rate: 0.0010
# Epoch 10/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8683 - loss: 0.3221
# Epoch 10: val_loss did not improve from 0.44309
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8684 - loss: 0.3220 - val_accuracy: 0.7789 - val_loss: 0.5145 - learning_rate: 0.0010
# Epoch 11/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8761 - loss: 0.3045
# Epoch 11: val_loss improved from 0.44309 to 0.41552, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8764 - loss: 0.3037 - val_accuracy: 0.8333 - val_loss: 0.4155 - learning_rate: 0.0010
# Epoch 12/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8938 - loss: 0.2496
# Epoch 12: val_loss improved from 0.41552 to 0.36162, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8937 - loss: 0.2503 - val_accuracy: 0.8946 - val_loss: 0.3616 - learning_rate: 0.0010
# Epoch 13/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9046 - loss: 0.2411
# Epoch 13: val_loss did not improve from 0.36162
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9046 - loss: 0.2409 - val_accuracy: 0.8741 - val_loss: 0.3694 - learning_rate: 0.0010
# Epoch 14/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9130 - loss: 0.2100
# Epoch 14: val_loss improved from 0.36162 to 0.34603, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9131 - loss: 0.2100 - val_accuracy: 0.8844 - val_loss: 0.3460 - learning_rate: 0.0010
# Epoch 15/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9186 - loss: 0.1941
# Epoch 15: val_loss improved from 0.34603 to 0.34141, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9183 - loss: 0.1946 - val_accuracy: 0.8878 - val_loss: 0.3414 - learning_rate: 0.0010
# Epoch 16/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9194 - loss: 0.1807
# Epoch 16: val_loss improved from 0.34141 to 0.33247, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9194 - loss: 0.1807 - val_accuracy: 0.8946 - val_loss: 0.3325 - learning_rate: 0.0010
# Epoch 17/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9418 - loss: 0.1429
# Epoch 17: val_loss improved from 0.33247 to 0.30629, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9413 - loss: 0.1441 - val_accuracy: 0.9082 - val_loss: 0.3063 - learning_rate: 0.0010
# Epoch 18/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9324 - loss: 0.1591
# Epoch 18: val_loss did not improve from 0.30629
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9326 - loss: 0.1590 - val_accuracy: 0.9048 - val_loss: 0.3240 - learning_rate: 0.0010
# Epoch 19/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9430 - loss: 0.1318
# Epoch 19: val_loss improved from 0.30629 to 0.26382, saving model to /kaggle/working/neuroscan_best.keras
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9428 - loss: 0.1322 - val_accuracy: 0.9184 - val_loss: 0.2638 - learning_rate: 0.0010
# Epoch 20/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9406 - loss: 0.1445
# Epoch 20: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9407 - loss: 0.1444 - val_accuracy: 0.9116 - val_loss: 0.3058 - learning_rate: 0.0010
# Epoch 21/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9628 - loss: 0.1072
# Epoch 21: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9623 - loss: 0.1078 - val_accuracy: 0.9150 - val_loss: 0.2678 - learning_rate: 0.0010
# Epoch 22/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9531 - loss: 0.1051
# Epoch 22: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9531 - loss: 0.1057 - val_accuracy: 0.9150 - val_loss: 0.2687 - learning_rate: 0.0010
# Epoch 23/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9548 - loss: 0.1141
# Epoch 23: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9549 - loss: 0.1140 - val_accuracy: 0.9252 - val_loss: 0.2880 - learning_rate: 0.0010
# Epoch 24/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9616 - loss: 0.1000
# Epoch 24: val_loss did not improve from 0.26382
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9617 - loss: 0.0992 - val_accuracy: 0.9116 - val_loss: 0.3242 - learning_rate: 0.0010
# Epoch 25/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9708 - loss: 0.0766
# Epoch 25: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9705 - loss: 0.0770 - val_accuracy: 0.9218 - val_loss: 0.3200 - learning_rate: 5.0000e-04
# Epoch 26/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9677 - loss: 0.0708
# Epoch 26: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9678 - loss: 0.0706 - val_accuracy: 0.9252 - val_loss: 0.3133 - learning_rate: 5.0000e-04
# Epoch 27/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9823 - loss: 0.0488
# Epoch 27: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9820 - loss: 0.0493 - val_accuracy: 0.9184 - val_loss: 0.3347 - learning_rate: 5.0000e-04
# Epoch 28/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.9670 - loss: 0.0684
# Epoch 28: val_loss did not improve from 0.26382
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9672 - loss: 0.0683 - val_accuracy: 0.9014 - val_loss: 0.3468 - learning_rate: 5.0000e-04
# Epoch 29/100
# 41/42 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9700 - loss: 0.0646
# Epoch 29: val_loss did not improve from 0.26382
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9700 - loss: 0.0648 - val_accuracy: 0.9218 - val_loss: 0.3394 - learning_rate: 5.0000e-04
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Total runtime: 104.0911328792572 seconds

# %% [markdown]
# # **Accuracy and Loss**

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # **Confusion Matrix**

# %%
y_true = np.argmax(y_train, axis=1)
y_pred = np.argmax(model.predict(x_train), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true,y_pred), annot=True, fmt='d', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step

# %%
y_true_test = np.argmax(y_test, axis=1)
y_pred_test = np.argmax(model.predict(x_test), axis=1) 

heatmap = sns.heatmap(confusion_matrix(y_true_test,y_pred_test), annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# # **Evaluation**

# %%
print(classification_report(y_true_test,y_pred_test, target_names=labels))
# Out:
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.99      0.79      0.88       117
# meningioma_tumor       0.77      0.96      0.86        84
#         no_tumor       0.88      0.90      0.89        48
#  pituitary_tumor       0.96      0.99      0.97        78
#
#         accuracy                           0.90       327
#        macro avg       0.90      0.91      0.90       327
#     weighted avg       0.91      0.90      0.90       327

# %% [markdown]
# # **Prediction**

# %%
random_index = np.random.randint(0, len(x_test))
random_img = x_test[random_index]
predictions = model.predict(random_img.reshape(1, 256, 256, 3))

# Interpret the model's predictions
predicted_class = np.argmax(predictions)  # Get the index of the class with the highest probability
predicted_label = labels[predicted_class]  # Convert class to label
confidence = predictions[0][predicted_class]

actual_index = y_test[random_index]  # Get the one-hot encoded actual class
actual_class = np.argmax(actual_index)
actual_label = labels[actual_class]  

print(f"Predicted label: {predicted_label} \nActual label: {actual_label} \nConfidence: {confidence*100:.2f}%\n")
plt.figure(figsize = (3,3))
plt.imshow(random_img)
plt.axis('off')  
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Predicted label: pituitary_tumor
# Actual label: pituitary_tumor
# Confidence: 80.98%

# %% [markdown]
# # **Custom Data Prediction**

# %%
img_path = '/kaggle/input/test-dataset/no_tumor.jpg'
custom_actual_label = 'no_tumor'

custom_img_arr = []
tumor_img = cv2.imread(img_path)
tumor_img = cv2.resize(tumor_img,(256, 256))
custom_img_arr.append(tumor_img)
custom_img_arr = np.array(custom_img_arr)
custom_img_arr = custom_img_arr / 255

custom_pred = model.predict(custom_img_arr.reshape(1, 256, 256, 3))

custom_pred_class = np.argmax(custom_pred)
custom_pred_label = labels[custom_pred_class]
custom_pred_confidence = custom_pred[0][custom_pred_class]

# np.set_printoptions(threshold=20)
# print(t_img)

print(f"Predicted label: {custom_pred_label} \nActual label: {custom_actual_label} \nConfidence: {custom_pred_confidence*100:.2f}%\n")
plt.figure(figsize = (3,3))
plt.imshow(tumor_img)
plt.axis('off')  
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Predicted label: no_tumor
# Actual label: no_tumor
# Confidence: 100.00%
